# %%
#class Card(): __init__ | __str__
#class Deck(): __init__ | shuffle | deal_one
#class Player(): __init__ | add cards | remove one |  __str__

#game_setup

#create a new_deck variable
#shuffle the deck created
#split the deck into 2 equal parts between the players
#add a card to each players hand from the deck created
#check number of cards in player hand
#set the game to start
    #set a counter for each round
    #intiate the game on while loop
    #create a round counter and inform user what round 
    # Check to see if each player is out of cards - if they are end game
    #if not game continous - play a card from each hand to the table 
    # Create an "at war" variable and set it to True
    # Initiate the while loop, setting it to True    
        # Create the 3 scenarios:
        # SCENARIO 1: Player one wins the round and keeps the cards if their most recent card is higher
        # Hint: Compare the most recent cards (-1 index) and add played cards to player one's deck
        # End the war
    
        # SCENARIO 2: Player two wins the round and keeps the cards if their most recent card is higher
        # Hint: Compare the most recent cards (-1 index) and add played cards to player two's deck
    
        # SCENARIO 3: If the cards are equal, a war begins
        # Hint: Print "WAR", check if players have enough cards
        # If a player has less than 3 cards, they lose and the game ends
        # Otherwise, draw additional cards and add them to the played cards list

# %%
import random 

suits = ['Hearts', 'Diamonds', 'Spades', 'Clubs']
ranks = ['Two','Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'King', 'Queen', 'Ace']
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 
         'Queen':12,'King':13,'Ace':14}

# %%
class Card(): 
    
    def __init__(self,rank,suit):
        
        self.rank = rank 
        self.suit = suit 
        self.value = values[rank]
        
    def __str__(self):
        
        return f'{self.rank} of {self.suit}'

# %%
class Deck(): 
    
    def __init__(self):
        
        self.all_cards = []
        
        for rank in ranks:
            for suit in suits:
                created_cards = Card(rank,suit)
                self.all_cards.append(created_cards)
        
    def shuffle(self):
        
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        
        return self.all_cards.pop()

# %%
class Player():
    
    def __init__(self,name):
        
        self.name = name
        
        self.player_hand = []
        
    def add_cards(self,new_cards):
        
        if type(new_cards) == type([]):
            
            self.player_hand.extend(new_cards)
            
        else:
            
            self.player_hand.append(new_cards)
            
    def remove_one(self):
        
        return self.player_hand.pop(0)    
    
    def __str__(self):
        
        return f'{self.name} has {self.player_hand} card(s) in their hand'

# %%
#game setup: 

player_one = Player('Player One')
player_two = Player('Player Two')

deck = Deck()
deck.shuffle()

# %%
#split the deck into 2 equal parts between the players
len(deck.all_cards)/2
# Out:
# 26.0

# %%
#add a card to each players hand from the deck created
for card in range(26):
    player_one.add_cards(deck.deal_one())
    player_two.add_cards(deck.deal_one())
    
#check number of cards in player hand
len(player_one.player_hand)
# Out:
# 26

# %%
len(player_two.player_hand)
# Out:
# 26

# %%
game_on = True

round_num = 0
while game_on:
    
    round_num +=1
    print (f'Round {round_num}')
    
    if len(player_one.player_hand) == 0:
        print ('You have run out of cards. Player 2 wins!')
        game_on = False
        break
        
    if len(player_two.player_hand) == 0:
        print ('You have run out of cards. Player 1 wins!')
        game_on = False
        break
        
    player_one_cards_played = []
    player_one_cards_played.append(player_one.remove_one())
    
    player_two_cards_played = []
    player_two_cards_played.append(player_two.remove_one())
    
    at_war = True
    
    while at_war:
        
        if player_one_cards_played[-1].value > player_two_cards_played[-1].value:
            player_one.add_cards(player_one_cards_played)
            player_one.add_cards(player_two_cards_played)
            at_war = False
            
        
        elif player_one_cards_played[-1].value < player_two_cards_played[-1].value:
            player_two.add_cards(player_one_cards_played)
            player_two.add_cards(player_two_cards_played)
            at_war = False
            
            
        else:
            print('You are AT WAR')
            
            if len(player_one.player_hand) <5:
                print(f'{player_one.name} you do not have enough cards to go to war! Player 2 WINS')
                game_on = False
                break
            
            elif len (player_two.player_hand)<5:
                print(f'{player_two.name} you do not have enough cards to go to war! Player 1 WINS')
                game_on = False
                break
            
            else:
                for num in range(5):
                    player_one_cards_played.append(player_one.remove_one())
                    player_two_cards_played.append(player_two.remove_one())
# Out:
# Round 1
# You are AT WAR
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# You are AT WAR
# Round 13
# Round 14
# You are AT WAR
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# You are AT WAR
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# You are AT WAR
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# You are AT WAR
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# You are AT WAR
# Round 80
# ...
